# %% [markdown]
# <a href="https://colab.research.google.com/github/SelamBrook/Breakout-2/blob/main/Breakout2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Breakout-2-{YourGitHubUser}.git

# %% [markdown]
# # **Data Types and Arithmetic Operators Exercise**

# %% [markdown]
# 1. What is the result of 10.0 * 7?

# %%
'''
your code here
'''

# %% [markdown]
# 2. What is stored in result?

# %%
result = str(int(2.8))

# %% [markdown]
# 3. What is the final value and type of x?

# %%
x = int(float(-5))

# %% [markdown]
# 4. What is stored in expr? What is the order of operations?

# %%
expr = "a" + "b" * 2 + "c"

# %% [markdown]
# 5. What is the final value of value?

# %%
value = 100 / 5 // 4 * 3 % 5

# %% [markdown]
# 6. hat is the value of b? Why does this happen?

# %%
b = bool(0)

# %% [markdown]
# 7. Why are the results numerically the same but types different?

# %%
a = 4 * 3
b = 4 * 3.0

# %% [markdown]
# 8. Does calling int() on an int or float() on a float change the value? Why or why not?

# %%
x = int(5)
y = float(5.0)

# %% [markdown]
# 9. What is the value and type of x?

# %%
x = 2 ** 3

# %% [markdown]
# 10. What is the value of y?

# %%
y = 4 * 2 ** 2

# %% [markdown]
# 11. What is the value of a?

# %%
a = 5 - 1 + 4 * 2

# %% [markdown]
# 12. What is the value of b?

# %%
b = (5 - 1 + 4) * 2

# %% [markdown]
# 13. What are the values of b1 and b2? Are they the same? If not, why are they different?

# %%
b1 = bool("")
b2 = bool("False")

# %% [markdown]
# 14. Is (2 + 3) * 4 an expression or a function?

# %%
# your answer here

# %% [markdown]
# 15. What is the final value of result?

# %%
result = str(int(5.9) + 2 ** 2) * 2

# %% [markdown]
# # **Variables**

# %% [markdown]
# Song lyrics are often made up of multiple verses and a single chorus. Each verse differs from the others but the chorus is repeated. The code provided prints out the lyrics of the song "Traffic in the Sky" by Jack Johnson:

# %%
lyrics = """There's traffic in the sky
And it doesn't seem to be getting much better
There's kids playing games on the pavement
Drawing waves on the pavement, mhm
Shadows of the planes on the pavement, mhm
It's enough to make me cry
But that don't seem like it would make it feel better
Maybe it's a dream, and if I scream
It will burst at the seams
Whole place will fall into pieces
And then they'd say

Well how could we have known
I'll tell them it's not so hard to tell, no, no, no
If you keep adding stonks
Soon the water will be lost in the well, mhm

Puzzle pieces in the ground
No one ever seems to be digging
Instead, they're looking up towards the heavens
With their eyes on the heavens, mhm
The shadows on the way to the heavens, mhm
It's enough to make me cry
But that don't seem like it would make it feel better
The answers could be found
We could learn from digging down
But no one ever seems to be digging
Instead they'll say

Well how could we have known
I'll tell them it's not so hard to tell, no, no, no
If you keep adding stonks
Soon the water will be lost in the well, mhm

Words of wisdom all around
But no one ever seems to listen
They're talking about their plans on the paper
Building up from the pavement, mhm
The shadows from the scrapers on the pavement, mhm
It's enough to make me sigh
But that don't seem like it would make feel better
The words are all around
But the words are only sounds
And no one ever seems to listen
Instead they'll say

Well how could we have known
I'll tell them it's really not so hard to tell, no, no, no
If you keep adding stonks
Soon the water will be lost in the well, mhm
Lost in the well, mhmhm"""

print(lyrics)

# %% [markdown]
# ### Step 1
# Create four variables named verse1 , verse2 , verse3 , and chorus to store the string values of smaller pieces of the song lyrics. Print them out one at a time to display the entire song. Make sure to include empty print() statements for the blank lines.

# %%
# your code here

# %% [markdown]
# ### Step 2
# There is a typo in the chorus of the song lyrics. The lyrics printed out say "stonks" instead of "stones". Fix the typo in the value assigned to the chorus variable. Notice that since this was stored in a variable you only have to fix the typo one time instead of multiple times.

# %% [markdown]
# ### Step 3
# Notice that the final version of the chorus is slightly different from the previous two. Reassign the value of the chorus variable before printing out the chorus for the third time.

# %% [markdown]
# ## **Reference** **Section**
# Below are the topics you need to know to complete this task.

# %% [markdown]
# ### Variables
# We can store any value in a variable. A variable allows us to do two things:
#
# Give a name to a value. This helps to improve the readability of our code.
#
# Use the same value in multiple locations in our code without having to repeat it.
#
# A variable can only ever contain one value at a time. To create a variable and assign it a value, write a variable name followed by the = sign and then the value to be stored there. A variable name can never be changed. However, the value inside of it can be changed by assigning a new value. In order to access a variable, write the name of the variable in the place where you want the value to be used. For example:

# %%
my_favorite_color = 'blue'
print(my_favorite_color)
my_favorite_fruit = my_favorite_color + 'berries'
my_favorite_color = 'green'
print(my_favorite_color)
print(my_favorite_fruit)

# %% [markdown]
# ### Strings
# Strings are defined by a pair of either single or double quotes with text in between. Python has another special way of allowing longer, multi-line strings to be defined. You can use three double quotation marks """ at both the beginning and the end of a multi-line string. For example,

# %%
long_string = """Hello this is a long string
and it goes on and on and on
across multiple lines
it ends here!"""

print(long_string)

# %% [markdown]
# To print a blank line between statements you can call the print() function with no input. For example:

# %%
print('line1')
print()
print('line2')
